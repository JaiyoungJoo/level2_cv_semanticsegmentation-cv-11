# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import seaboern as sns
import os
import json
from dataset import XRayDataset, XRayDataset_path, XRayDataset_gray,XRayDataset_Multi
from torch.utils.data import DataLoader, Subset
import torch
import albumentations as A
import random
from tqdm.auto import tqdm
import torch.nn.functional as F
import torch.nn as nn

# %matplotlib inline

# %%
IMAGE_ROOT = "/opt/ml/input/data/train/DCM/"
LABEL_ROOT = "/opt/ml/input/data/train/outputs_json/"

CLASSES = [
    'finger-1', 'finger-2', 'finger-3', 'finger-4', 'finger-5',
    'finger-6', 'finger-7', 'finger-8', 'finger-9', 'finger-10',
    'finger-11', 'finger-12', 'finger-13', 'finger-14', 'finger-15',
    'finger-16', 'finger-17', 'finger-18', 'finger-19', 'Trapezium',
    'Trapezoid', 'Capitate', 'Hamate', 'Scaphoid', 'Lunate',
    'Triquetrum', 'Pisiform', 'Radius', 'Ulna',
]

BATCH_SIZE=8

# %%
# define colors
PALETTE = [
    (220, 20, 60), (119, 11, 32), (0, 0, 142), (0, 0, 230), (106, 0, 228),
    (0, 60, 100), (0, 80, 100), (0, 0, 70), (0, 0, 192), (250, 170, 30),
    (100, 170, 30), (220, 220, 0), (175, 116, 175), (250, 0, 30), (165, 42, 42),
    (255, 77, 255), (0, 226, 252), (182, 182, 255), (0, 82, 0), (120, 166, 157),
    (110, 76, 0), (174, 57, 255), (199, 100, 0), (72, 0, 118), (255, 179, 240),
    (0, 125, 92), (209, 0, 151), (188, 208, 182), (0, 220, 176),
]

# utility function
# this does not care overlap
def label2rgb(label):
    image_size = label.shape[1:] + (3, )
    image = np.zeros(image_size, dtype=np.uint8)
    
    for i, class_label in enumerate(label):
        image[class_label == 1] = PALETTE[i]
        
    return image

# %%
pngs = {
    os.path.relpath(os.path.join(root, fname), start=IMAGE_ROOT)
    for root, _dirs, files in os.walk(IMAGE_ROOT)
    for fname in files
    if os.path.splitext(fname)[1].lower() == ".png"
}

# %%
def dice_coef(y_true, y_pred):
    y_true_f = y_true.flatten(2)
    y_pred_f = y_pred.flatten(2)
    intersection = torch.sum(y_true_f * y_pred_f, -1)
    
    eps = 0.0001
    return (2. * intersection + eps) / (torch.sum(y_true_f, -1) + torch.sum(y_pred_f, -1) + eps)

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if use multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)

# %%
def make_dataset(debug="False"):
    # dataset load
    tf = A.Resize(1024,1024)
    train_dataset = XRayDataset_Multi(is_train=True, transforms=tf)
    valid_dataset = XRayDataset_Multi(is_train=False, transforms=tf)
    original_dataset = XRayDataset_path(is_train=False)
    if debug=="True":
        train_subset_size = int(len(train_dataset) * 0.2)

        # Create a random train subset of the original dataset
        train_subset_indices = range(len(train_dataset))[:train_subset_size]
        train_dataset = Subset(train_dataset, train_subset_indices)

        # Calculate the number of samples for the valid subset
        valid_subset_size = int(len(valid_dataset) * 0.2)
        # Create a random valid subset of the original dataset
        valid_subset_indices = range(len(valid_dataset))[:valid_subset_size]
        print(valid_subset_indices)

        valid_dataset = Subset(valid_dataset, valid_subset_indices)

        original_dataset = Subset(original_dataset, valid_subset_indices)
        
    train_loader = DataLoader(
        dataset=train_dataset, 
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=8,
        drop_last=True,
    )

    valid_loader = DataLoader(
        dataset=valid_dataset, 
        batch_size=2,
        shuffle=False,
        num_workers=0,
        drop_last=False
    )

    original_loader = DataLoader(
        dataset=original_dataset, 
        batch_size=2,
        shuffle=False,
        num_workers=0,
        drop_last=False
    )

    return [train_loader, valid_loader, original_loader]

# %%
def make_graydataset(debug="False"):
    # dataset load
    # tf = A.Resize(512, 512)
    tf = None
    train_dataset = XRayDataset_gray(is_train=True, transforms=tf)
    valid_dataset = XRayDataset_gray(is_train=False, transforms=tf)
    original_dataset = XRayDataset_path(is_train=False)
    if debug=="True":
        train_subset_size = int(len(train_dataset) * 0.2)

        # Create a random train subset of the original dataset
        train_subset_indices = range(len(train_dataset))[:train_subset_size]
        train_dataset = Subset(train_dataset, train_subset_indices)

        # Calculate the number of samples for the valid subset
        valid_subset_size = int(len(valid_dataset) * 0.2)

        # Create a random valid subset of the original dataset
        valid_subset_indices = range(len(valid_dataset))[:valid_subset_size]
        print(valid_subset_indices)
        valid_dataset = Subset(valid_dataset, valid_subset_indices)
        original_dataset = Subset(original_dataset, valid_subset_indices)
        
    train_loader = DataLoader(
        dataset=train_dataset, 
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=8,
        drop_last=True,
    )

    valid_loader = DataLoader(
        dataset=valid_dataset, 
        batch_size=1,
        shuffle=False,
        num_workers=0,
        drop_last=False
    )

    original_loader = DataLoader(
        dataset=original_dataset, 
        batch_size=2,
        shuffle=False,
        num_workers=0,
        drop_last=False
    )

    return [train_loader, valid_loader, original_loader]

# %% [markdown]
# # Visualizing images

# %%
def validation(epoch, model, data_loader, criterion, thr=0.5):
    print(f'Start validation #{epoch:2d}')
    model.eval()

    dices = []
    all_dices = []
    all_masks = []
    with torch.no_grad():
        total_loss = 0
        cnt = 0
    
        for step, (images, masks) in tqdm(enumerate(data_loader)):
            images, masks = images.cuda(), masks.cuda()         
            model = model.cuda()
            
            outputs = model(images)
            
            output_h, output_w = outputs.size(-2), outputs.size(-1)
            mask_h, mask_w = masks.size(-2), masks.size(-1)
            
            # restore original size
            if output_h != mask_h or output_w != mask_w:
                outputs = F.interpolate(outputs, size=(mask_h, mask_w), mode="bilinear")
            
            outputs = torch.sigmoid(outputs)
            outputs = (outputs > thr).detach().cpu()
            masks = masks.detach().cpu()
            all_masks.append(np.array(outputs))
            dice = dice_coef(outputs, masks)
            all_dices.append(dice.mean(axis=1))
            dices.append(dice)
    dices = torch.cat(dices, 0)
    return [all_masks, all_dices]

# %%
def save_image(epoch, data_loader):
    print(f'Start validation #{epoch:2d}')
    all_images=[]
    all_masks=[]
    all_paths=[]
    for step, (images, masks, path) in tqdm(enumerate(data_loader)):
        all_images.append(np.array(images))
        all_masks.append(np.array(masks))
        all_paths.append(path)
    return [all_images, all_masks, all_paths]

# %%
model_gray = torch.load("/opt/ml/input/weights/gray_FPN_gray_resnet101_True_comb_loss_100.pt")
model = torch.load("/opt/ml/input/weights/MultiModalV4_HR_150_noseedup/Pretrained_Multimodal_HR_200.pt")

# %%
set_seed(21)
train_loader, valid_loader, original_loader = make_dataset(debug="True")
criterion = nn.BCEWithLogitsLoss()

train_loader_gray, valid_loader_gray, original_loader_gray = make_graydataset(debug="True")
# Out:
# range(0, 32)
# range(0, 32)

# %%
def validation_multi(epoch, model, data_loader, criterion, thr=0.5):
    print(f'Start validation #{epoch:2d}')
    model.eval()

    dices = []
    all_dices = []
    all_masks = []
    with torch.no_grad():
        total_loss = 0
        cnt = 0
        
        
        for step, (images, masks, ages, genders, weights, heights) in tqdm(enumerate(data_loader), total=len(data_loader)):
            images, masks, ages, genders, weights, heights = images.cuda(), masks.cuda(), ages.cuda(), genders.cuda(), weights.cuda(), heights.cuda()     
            model = model.cuda()
            
            outputs, ages_, genders_, weights_, heights_ = model(images, ages, genders, weights, heights)
            
            output_h, output_w = outputs.size(-2), outputs.size(-1)
            mask_h, mask_w = masks.size(-2), masks.size(-1)
            
            # restore original size
            if output_h != mask_h or output_w != mask_w:
                outputs = F.interpolate(outputs, size=(mask_h, mask_w), mode="bilinear")
            
            outputs = torch.sigmoid(outputs)
            outputs = (outputs > thr).detach().cpu()
            masks = masks.detach().cpu()
            all_masks.append(np.array(outputs))
            dice = dice_coef(outputs, masks)
            all_dices.append(dice.mean(axis=1))
            dices.append(dice)
    dices = torch.cat(dices, 0)
    return [all_masks, all_dices]

# %%
masks, dices = validation(1, model, valid_loader, criterion)    #메모리 이슈로 이미지 절반(40)만 추출합니다
# Out:
# Start validation # 1
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=16.0), HTML(value='')))

# %%
masks_gray, dices_gray = validation(1, model_gray, valid_loader_gray, criterion)    #메모리 이슈로 이미지 절반(40)만 추출합니다
# Out:
# Start validation # 1
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…

# %%
gtimage, gtmask, gtpath = save_image(1, original_loader)
# Out:
# Start validation # 1
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…

# %%
masks = np.concatenate(masks, axis=0)   #predicetd mask
dices = np.concatenate(dices, axis=0)   #predicted labels' dices

gtimage = np.concatenate(gtimage, axis=0)   #GT image(2048, 2048)
gtmask = np.concatenate(gtmask, axis=0)    #GT mask(2048, 2048)
gtpath = np.concatenate(gtpath, axis=0)     #image path

masks_gray = np.concatenate(masks_gray, axis=0)     #image path
dices_gray = np.concatenate(dices_gray, axis=0)     #image path

# %%
print(masks.shape)
print(dices.shape)
print(gtimage.shape)
print(gtmask.shape)
print(gtpath.shape)

print(masks_gray.shape)
print(dices_gray.shape)
# Out:
# (32, 29, 2048, 2048)
# (32,)
# (32, 3, 2048, 2048)
# (32, 29, 2048, 2048)
# (32,)
# (32, 1, 2048, 2048)
# (32,)

# %%
# temp = torch.logical_not(torch.eq(torch.sum(torch.tensor(gtmask), dim=1, keepdim=True), 0)).float()
# gtmask = np.array(temp)

# %%
gtpath = [i.split("/")[-2]+"_"+i.split("/")[-1] for i in gtpath]

# %%
tp = np.logical_and(gtmask, masks)
# fn = gtmask - masks
# fp = masks - gtmask

# %%
#이미지 저장경로 설정
model_path = "MAnet/"     #원하는 폴더명 입력
path = "/opt/ml/statimages/"
path = os.path.join(path, model_path)

if not os.path.isdir(path):                                                           
    os.makedirs(path, exist_ok=True)

# %%
for i in tqdm(range(len(dices))):
    INDEX = i

    fig, ax = plt.subplots(1, 4, figsize=(16, 5))
    ax = ax.flatten()
    fig.suptitle("Image index: " + str(gtpath[INDEX]) +"\nDice: " + str(dices[INDEX]), fontsize=15)
    ax[0].imshow(gtimage[INDEX][0])   # remove channel dimension
    ax[1].imshow(gtimage[INDEX][0])   # remove channel dimension
    ax[2].imshow(gtimage[INDEX][0])   # remove channel dimension
    ax[3].imshow(gtimage[INDEX][0])   # remove channel dimension
    ax[0].axis("off")
    ax[1].axis("off")
    ax[2].axis("off")
    ax[3].axis("off")
    ax[0].set_title("GT")
    ax[1].set_title("TP")
    ax[2].set_title("FN")
    ax[3].set_title("FP")


    ax[0].imshow(label2rgb(gtmask[INDEX]), alpha=0.5)
    ax[1].imshow(label2rgb(tp[INDEX]), alpha=0.5)
    ax[2].imshow(label2rgb(gtmask[INDEX] - masks[INDEX]), alpha=0.7)
    ax[3].imshow(label2rgb(masks[INDEX] - gtmask[INDEX]), alpha=0.7)
    break

    plt.savefig(f"{path}{str(dices[INDEX])}_{gtpath[INDEX]}", dpi=300, bbox_inches = "tight")
    plt.close(fig)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=32.0), HTML(value='')))

# %%
temp  =np.logical_and(masks, masks_gray)

# %%
(dice_coef(torch.tensor(gtmask,dtype=torch.bool), torch.tensor(masks,dtype=torch.bool)).mean(axis=0))
# Out:
# tensor([0.9747, 0.9842, 0.9798, 0.9756, 0.9780, 0.9839, 0.9701, 0.9777, 0.9797,
#         0.9862, 0.9735, 0.9776, 0.9794, 0.9838, 0.9791, 0.9725, 0.9738, 0.9835,
#         0.9832, 0.9723, 0.9655, 0.9719, 0.9722, 0.9808, 0.9769, 0.9740, 0.9650,
#         0.9894, 0.9887])

# %%
(dice_coef(torch.tensor(gtmask,dtype=torch.bool), torch.tensor(temp,dtype=torch.bool)).mean(axis=0))
# Out:
# tensor([0.9752, 0.9849, 0.9802, 0.9758, 0.9778, 0.9849, 0.9708, 0.9778, 0.9795,
#         0.9867, 0.9745, 0.9775, 0.9791, 0.9845, 0.9797, 0.9729, 0.9747, 0.9841,
#         0.9838, 0.9721, 0.9655, 0.9719, 0.9723, 0.9808, 0.9766, 0.9739, 0.9647,
#         0.9896, 0.9894])

# %%
torch.tensor([0.9720, 0.9843, 0.9853, 0.9741, 0.9782, 0.9870, 0.9837, 0.9766, 0.9786,
        0.9877, 0.9754, 0.9756, 0.9800, 0.9856, 0.9804, 0.9699, 0.9693, 0.9840,
        0.9851, 0.9495, 0.9158, 0.9635, 0.9535, 0.9713, 0.9573, 0.9487, 0.8851,
        0.9894, 0.9886]).mean()
# Out:
# tensor(0.9702)

# %%
for i, v in enumerate([0.9572, 0.9758, 0.9817, 0.9599, 0.9657, 0.9805, 0.9738, 0.9633, 0.9694,
        0.9799, 0.9681, 0.9617, 0.9700, 0.9786, 0.9687, 0.9496, 0.9589, 0.9767,
        0.9741, 0.9322, 0.9036, 0.9495, 0.9420, 0.9536, 0.9412, 0.9423, 0.8631,
        0.9853, 0.9829]):
    print(CLASSES[i], v)
# Out:
# finger-1 0.9572
# finger-2 0.9758
# finger-3 0.9817
# finger-4 0.9599
# finger-5 0.9657
# finger-6 0.9805
# finger-7 0.9738
# finger-8 0.9633
# finger-9 0.9694
# finger-10 0.9799
# finger-11 0.9681
# finger-12 0.9617
# finger-13 0.97
# finger-14 0.9786
# finger-15 0.9687
# finger-16 0.9496
# finger-17 0.9589
# finger-18 0.9767
# finger-19 0.9741
# Trapezium 0.9322
# Trapezoid 0.9036
# Capitate 0.9495
# Hamate 0.942
# Scaphoid 0.9536
# Lunate 0.9412
# Triquetrum 0.9423
# Pisiform 0.8631
# Radius 0.9853
# Ulna 0.9829

# %%
for i in tqdm(range(len(dices))):
    INDEX = i

    fig, ax = plt.subplots(1, 4, figsize=(16, 5))
    ax = ax.flatten()
    fig.suptitle("Image index: " + str(gtpath[INDEX]) +"\nDice: " + str(dices[INDEX]), fontsize=15)
    ax[0].imshow(gtimage[INDEX][0])   # remove channel dimension
    ax[1].imshow(gtimage[INDEX][0])   # remove channel dimension
    ax[2].imshow(gtimage[INDEX][0])   # remove channel dimension
    ax[3].imshow(gtimage[INDEX][0])   # remove channel dimension
    ax[0].axis("off")
    ax[1].axis("off")
    ax[2].axis("off")
    ax[3].axis("off")
    ax[0].set_title("GT")
    ax[1].set_title("TP")
    ax[2].set_title("FN")
    ax[3].set_title("FP")


    ax[0].imshow(label2rgb(gtmask[INDEX]), alpha=0.5)
    ax[1].imshow(label2rgb(temp[INDEX]), alpha=0.5)
    ax[2].imshow(label2rgb(gtmask[INDEX] - temp[INDEX]), alpha=0.7)
    ax[3].imshow(label2rgb(temp[INDEX] - gtmask[INDEX]), alpha=0.7)
    break

    plt.savefig(f"{path}{str(dices[INDEX])}_{gtpath[INDEX]}", dpi=300, bbox_inches = "tight")
    plt.close(fig)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=32.0), HTML(value='')))
